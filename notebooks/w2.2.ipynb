# %% [markdown]
# # Data Types
#
# ## Simple Data Types
#
# - string (str)
# - integer (int)
# - float (float)
# - boolean (bool)
#
# ## Complex Data Types
#
# - list (list)
# - tuple (tuple)
# - dictionary (dict)
# - set (set)
#
# ## Dates
#
# - Dates and datetime

# %%
# String

my_string = "This is my string."
print(my_string)
# Out:
# This is my string.

# %%
my_string = "This is my new string"
print(my_string)
# Out:
# This is my new string

# %%
print(my_string.upper())
print(my_string)
# Out:
# THIS IS MY NEW STRING
# This is my new string

# %%
# index of collection
print(len(my_string))
my_string[0]
# Out:
# 21
# 'T'

# %%
my_string[-1]
# Out:
# 'g'

# %%
my_string[-3]
# Out:
# 'i'

# %%
print(my_string)
ending = "This is the End"
print(ending)
my_string = my_string + ending
print(my_string)
# Out:
# This is my new string
# This is the End
# This is my new stringThis is the End

# %%
my_string: str = "It will work without the hint"

# %%
# Integers
a: int = 26
b: int = 5

print("addition: ", a + b) # addition
print(f"division: {a/b}") # division
print(f"multiply: {a*b}") # multiplication
print(f"subratc: {a-b}") # subtraction
print(f"exponent: {a**b}") # exponents
print(f"floor division: {a//b}") # floor division
print(f"modulus: {a % b}") # modulus
# Out:
# addition:  31
# division: 5.2
# multiply: 130
# subratc: 21
# exponent: 11881376
# floor division: 5
# modulus: 1

# %%
a = str(a)
b = float(b) 

print(f" new type a and b: {a.zfill(7), b}")
print(int(3.99999))
# Out:
#  new type a and b: ('0000026', 5.0)
# 3

# %%
# booleans
x: bool = True
print(f"x = {x}")
print(f"b as bool: {bool(b)}")
print(f"0 as bool: {bool(0)}")
print(f"empty string as bool: {bool('')}")
print(f"a string as bool: {bool(a)}")
# Out:
# x = True
# b as bool: True
# 0 as bool: False
# empty string as bool: False
# a string as bool: True

# %%
# List
# ordered (index)
# mutable
# allows repeted values

my_list = [1,2,"3", False, [1,2,3]]

# %%
my_list[-1]
list2 = list((1,2,3))
print(list2)
print(list2.pop())
print(list2)
list2.pop()
print(list2)
# Out:
# [1, 2, 3]
# 3
# [1, 2]
# [1]

# %%
l1 = []
l1.append(1)
print(l1)
l1.append(2)
print(l1)
l1.pop()
print(l1)
# Out:
# [1]
# [1, 2]
# [1]

# %%
l2 = [1,2,3]
l2.pop(0)
# Out:
# 1

# %%
l2.pop()
# Out:
# [2, 3]

# %%
pawns = ["p"] * 8
cool = ["r", "k", "b", "q", "k", "b", "k", "r"]
empty = [""] * 8
chess = [
    cool.copy(),
    pawns.copy(),
    empty.copy(),
    empty.copy(),
    empty.copy(),
    empty.copy(),
    pawns.copy(),
    cool.copy()
]
chess
# Out:
# [['r', 'k', 'b', 'q', 'k', 'b', 'k', 'r'],
#  ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'],
#  ['r', 'k', 'b', 'q', 'k', 'b', 'k', 'r']]

# %%
chess[0][1] = ""
chess[2][0] = "k"
chess
# Out:
# [['r', '', 'b', 'q', 'k', 'b', 'k', 'r'],
#  ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'],
#  ['k', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'],
#  ['r', 'k', 'b', 'q', 'k', 'b', 'k', 'r']]
